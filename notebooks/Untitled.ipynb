# %% [markdown]
# ## Inserting data into Elasticsearch
# Before you can query Elasticsearch, you will need to load some data into an index. In
# the previous section, you used a library, psycopg2, to access PostgreSQL. To access Elasticsearch, you will use the elasticsearch library. To load data, you need to create the connection, then you can issue commands to Elasticsearch. Follow the given steps to add a record to Elasticsearch:

# %% [markdown]
# 1. Import the libraries. You can also create the Faker object to generate random data:

# %%
from elasticsearch import Elasticsearch
from faker import Faker

fake=Faker()

# %% [markdown]
# 2. Create a connection to Elasticsearch:

# %%
es = Elasticsearch()

# %% [markdown]
# 3. The preceding code assumes that your Elasticsearch instance is running on localhost. If it is not, you can specify the IP address, as shown:

# %%
es=Elasticsearch({'127.0.0.1'})

# %%
doc={"name": fake.name(),"street": fake.street_address(),"city": fake.city(),"zip":fake.zipcode()}
res=es.index(index="users",body=doc)

# %%
print(res['result']) #created
# Out:
# created

# %%
res
# Out:
# {'_index': 'users',
#  '_type': '_doc',
#  '_id': 'E5wNYHgBgZXbBKAYBJ_U',
#  '_version': 1,
#  'result': 'created',
#  '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#  '_seq_no': 0,
#  '_primary_term': 1}

# %% [markdown]
# ## Inserting data using helpers
# Using the bulk method, you can insert many documents at a time. The process is similar to inserting a single record, except that you will generate all the data, then insert it. The steps are as follows:

# %% [markdown]
# 1. You need to import the helpers library to access the bulk method:

# %%
from elasticsearch import helpers

# %%
actions = [
    {
        "_index": "users",
        "_source": {
        "name": fake.name(),
        "street": fake.street_address(),
        "city": fake.city(),
        "zip":fake.zipcode()}
    }
    for x in range(998) # or for i,r in df.iterrows()
]

# %%
actions
# Out:
# [{'_index': 'users',
#   '_source': {'name': 'Tammy Reyes',
#    'street': '3981 Ronnie Wells',
#    'city': 'Hannahland',
#    'zip': '83342'}},
#  {'_index': 'users',
#   '_source': {'name': 'Micheal Wilson',
#    'street': '6214 Jason Orchard Apt. 150',
#    'city': 'Harrishaven',
#    'zip': '36760'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jeffery Chen',
#    'street': '228 Allison Manors',
#    'city': 'Port Jessica',
#    'zip': '37875'}},
#  {'_index': 'users',
#   '_source': {'name': 'Bryce Drake',
#    'street': '181 Haley Stream Suite 205',
#    'city': 'Ethanton',
#    'zip': '47114'}},
#  {'_index': 'users',
#   '_source': {'name': 'James Hodges',
#    'street': '8741 Aaron Stravenue',
#    'city': 'West Morgan',
#    'zip': '56433'}},
#  {'_index': 'users',
#   '_source': {'name': 'Isabel Sandoval',
#    'street': '5214 Norris Lodge',
#    'city': 'South Heather',
#    'zip': '07033'}},
#  {'_index': 'users',
#   '_source': {'name': 'Erica Mayo',
#    'street': '6577 Rogers Road Suite 340',
#    'city': 'Maryton',
#    'zip': '19551'}},
#  {'_index': 'users',
#   '_source': {'name': 'Molly Jones',
#    'street': '680 Rice Inlet',
#    'city': 'Lake Joelland',
#    'zip': '16025'}},
#  {'_index': 'users',
#   '_source': {'name': 'Megan Kelly',
#    'street': '323 Christopher Flat',
#    'city': 'Chadville',
#    'zip': '85058'}},
#  {'_index': 'users',
#   '_source': {'name': 'Crystal Graham',
#    'street': '70221 Bishop Village Apt. 961',
#    'city': 'West Megan',
#    'zip': '60334'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mark Miller',
#    'street': '2592 Rogers Street',
#    'city': 'Jessicafurt',
#    'zip': '98941'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jerry Brown',
#    'street': '22211 Harvey Summit',
#    'city': 'Fosterchester',
#    'zip': '36820'}},
#  {'_index': 'users',
#   '_source': {'name': 'Victoria Solis',
#    'street': '501 Fuentes Crest Apt. 203',
#    'city': 'Robinsonville',
#    'zip': '99622'}},
#  {'_index': 'users',
#   '_source': {'name': 'Melinda Frey',
#    'street': '2445 Bennett Cliffs Apt. 056',
#    'city': 'Sullivanchester',
#    'zip': '41815'}},
#  {'_index': 'users',
#   '_source': {'name': 'Victoria Johnson',
#    'street': '0285 Rogers Trafficway Suite 047',
#    'city': 'Mckinneyberg',
#    'zip': '26847'}},
#  {'_index': 'users',
#   '_source': {'name': 'Peter Rodgers',
#    'street': '74954 Reynolds Union Apt. 585',
#    'city': 'Port Allen',
#    'zip': '12235'}},
#  {'_index': 'users',
#   '_source': {'name': 'Rachel Bullock',
#    'street': '441 Graham Pass Apt. 719',
#    'city': 'Danielbury',
#    'zip': '46719'}},
#  {'_index': 'users',
#   '_source': {'name': 'Emily Garcia',
#    'street': '01664 Robert Port',
#    'city': 'New Deborah',
#    'zip': '97474'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mrs. Jamie Kelly',
#    'street': '332 Patrick Park',
#    'city': 'Jenniferville',
#    'zip': '05673'}},
#  {'_index': 'users',
#   '_source': {'name': 'Amber Smith',
#    'street': '8752 Allison Route',
#    'city': 'West Marialand',
#    'zip': '81769'}},
#  {'_index': 'users',
#   '_source': {'name': 'Howard Sherman',
#    'street': '1787 Hunt Stravenue',
#    'city': 'Kathleenberg',
#    'zip': '06626'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jennifer Hudson',
#    'street': '3828 Savannah Mission Apt. 220',
#    'city': 'Colleenhaven',
#    'zip': '75565'}},
#  {'_index': 'users',
#   '_source': {'name': 'Claire Coleman',
#    'street': '75116 Deanna Throughway',
#    'city': 'East Ryan',
#    'zip': '45337'}},
#  {'_index': 'users',
#   '_source': {'name': 'Joseph Vega',
#    'street': '900 Rose Plain',
#    'city': 'Heatherside',
#    'zip': '44585'}},
#  {'_index': 'users',
#   '_source': {'name': 'Anthony Adams',
#    'street': '0115 Knight Ferry',
#    'city': 'Melaniemouth',
#    'zip': '81817'}},
#  {'_index': 'users',
#   '_source': {'name': 'Zachary Flores',
#    'street': '93633 Gabriela Light Suite 567',
#    'city': 'Morrowborough',
#    'zip': '56544'}},
#  {'_index': 'users',
#   '_source': {'name': 'Ashley Henry',
#    'street': '1145 Medina Parkway',
#    'city': 'Port Jennifer',
#    'zip': '74844'}},
#  {'_index': 'users',
#   '_source': {'name': 'Calvin Stephens',
#    'street': '99510 Friedman Garden Suite 932',
#    'city': 'Nelsonfort',
#    'zip': '99390'}},
#  {'_index': 'users',
#   '_source': {'name': 'James Washington',
#    'street': '4693 Melanie Keys Suite 941',
#    'city': 'Kevinville',
#    'zip': '91367'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jennifer Young',
#    'street': '98306 Bryan Land',
#    'city': 'North Danielside',
#    'zip': '78556'}},
#  {'_index': 'users',
#   '_source': {'name': 'Christian Valenzuela',
#    'street': '166 Brian Throughway',
#    'city': 'East Brian',
#    'zip': '45501'}},
#  {'_index': 'users',
#   '_source': {'name': 'Veronica Gonzalez',
#    'street': '485 Omar Ranch',
#    'city': 'Spencermouth',
#    'zip': '68644'}},
#  {'_index': 'users',
#   '_source': {'name': 'Sherry Byrd',
#    'street': '8490 Andrew Cape',
#    'city': 'Wrightchester',
#    'zip': '31571'}},
#  {'_index': 'users',
#   '_source': {'name': 'Caitlin Miller',
#    'street': '8683 Darin River Suite 342',
#    'city': 'Mccoyhaven',
#    'zip': '68547'}},
#  {'_index': 'users',
#   '_source': {'name': 'Allen Flores',
#    'street': '263 Michele Union Apt. 980',
#    'city': 'Port Shannonburgh',
#    'zip': '66708'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mark Frey',
#    'street': '576 Alexander Harbors Apt. 763',
#    'city': 'New Kayla',
#    'zip': '18227'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jennifer Martin',
#    'street': '22922 Perez Crest Suite 261',
#    'city': 'New Hollyton',
#    'zip': '96678'}},
#  {'_index': 'users',
#   '_source': {'name': 'Eric Mcdonald',
#    'street': '903 Reed Neck Apt. 353',
#    'city': 'Millerburgh',
#    'zip': '41129'}},
#  {'_index': 'users',
#   '_source': {'name': 'Beth Vega',
#    'street': '780 Ibarra Views',
#    'city': 'Amyfurt',
#    'zip': '67368'}},
#  {'_index': 'users',
#   '_source': {'name': 'Curtis Johnson',
#    'street': '1005 Gallagher Fork Suite 851',
#    'city': 'Karenchester',
#    'zip': '89540'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mr. Stephen Garcia',
#    'street': '4672 Robert Valleys Apt. 514',
#    'city': 'Arroyoville',
#    'zip': '21535'}},
#  {'_index': 'users',
#   '_source': {'name': 'Cory Scott',
#    'street': '162 Kristin Divide Suite 452',
#    'city': 'Charlesmouth',
#    'zip': '27437'}},
#  {'_index': 'users',
#   '_source': {'name': 'Larry Gomez',
#    'street': '825 Cruz Road Apt. 521',
#    'city': 'Diazview',
#    'zip': '16527'}},
#  {'_index': 'users',
#   '_source': {'name': 'Ronald Williams',
#    'street': '969 Hughes Place Apt. 350',
#    'city': 'Smithmouth',
#    'zip': '50537'}},
#  {'_index': 'users',
#   '_source': {'name': 'Joseph Thomas',
#    'street': '13125 Glenn Turnpike Suite 368',
#    'city': 'Hillville',
#    'zip': '67064'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jessica Mcgrath',
#    'street': '92606 Juan Fall Apt. 012',
#    'city': 'Port Danmouth',
#    'zip': '42977'}},
#  {'_index': 'users',
#   '_source': {'name': 'Shawna Howard',
#    'street': '6489 Timothy River Suite 420',
#    'city': 'Michaelport',
#    'zip': '79224'}},
#  {'_index': 'users',
#   '_source': {'name': 'Rachel Hernandez',
#    'street': '25451 Mclean Villages',
#    'city': 'South Anthonyport',
#    'zip': '53223'}},
#  {'_index': 'users',
#   '_source': {'name': 'Wesley Alexander',
#    'street': '410 Stacey Pines',
#    'city': 'New Tabitha',
#    'zip': '81012'}},
#  {'_index': 'users',
#   '_source': {'name': 'Amy Lynch',
#    'street': '76476 Smith Plains',
#    'city': 'Port Charles',
#    'zip': '91345'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jacob Smith',
#    'street': '43042 Turner Forks Suite 068',
#    'city': 'Brownville',
#    'zip': '21583'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jeremiah Brown',
#    'street': '32027 Scott Islands Suite 382',
#    'city': 'New Greg',
#    'zip': '75182'}},
#  {'_index': 'users',
#   '_source': {'name': 'Ashley Bass',
#    'street': '766 Murphy Neck Suite 880',
#    'city': 'Derrickbury',
#    'zip': '91545'}},
#  {'_index': 'users',
#   '_source': {'name': 'Patrick Gregory',
#    'street': '19037 Kimberly Coves Apt. 804',
#    'city': 'Jamesburgh',
#    'zip': '54554'}},
#  {'_index': 'users',
#   '_source': {'name': 'Rachel Johnson',
#    'street': '767 Pearson Harbor',
#    'city': 'Brianmouth',
#    'zip': '02701'}},
#  {'_index': 'users',
#   '_source': {'name': 'Elizabeth Jones',
#    'street': '469 Sarah Rest Suite 716',
#    'city': 'Lake Christopher',
#    'zip': '20121'}},
#  {'_index': 'users',
#   '_source': {'name': 'Joseph Brown',
#    'street': '8269 Marissa Keys Apt. 740',
#    'city': 'Jenkinsberg',
#    'zip': '90201'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jacqueline Holloway',
#    'street': '8960 Myers Ways',
#    'city': 'New Denisebury',
#    'zip': '84194'}},
#  {'_index': 'users',
#   '_source': {'name': 'Zachary Thompson',
#    'street': '1884 Miller Harbor Suite 578',
#    'city': 'Christianberg',
#    'zip': '53362'}},
#  {'_index': 'users',
#   '_source': {'name': 'Whitney Rogers',
#    'street': '3052 Sharon Canyon',
#    'city': 'East Yolandaburgh',
#    'zip': '22386'}},
#  {'_index': 'users',
#   '_source': {'name': 'Erin Wilson DVM',
#    'street': '1863 Michelle Points',
#    'city': 'New Michellebury',
#    'zip': '67682'}},
#  {'_index': 'users',
#   '_source': {'name': 'Curtis Phillips',
#    'street': '94800 Heather Centers',
#    'city': 'Evansmouth',
#    'zip': '75508'}},
#  {'_index': 'users',
#   '_source': {'name': 'Sarah Ayala',
#    'street': '11299 Richard Common',
#    'city': 'Hooverfort',
#    'zip': '79888'}},
#  {'_index': 'users',
#   '_source': {'name': 'Laura Singleton',
#    'street': '19784 Campbell Mountain Apt. 940',
#    'city': 'Lake Richardland',
#    'zip': '98782'}},
#  {'_index': 'users',
#   '_source': {'name': 'Amanda Miller',
#    'street': '47529 Mcdonald Skyway',
#    'city': 'Francisville',
#    'zip': '96652'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kimberly Foster',
#    'street': '15246 King Lodge Suite 527',
#    'city': 'North Adriennestad',
#    'zip': '07468'}},
#  {'_index': 'users',
#   '_source': {'name': 'Robert Morgan',
#    'street': '84689 Liu Park Apt. 483',
#    'city': 'Carrillotown',
#    'zip': '23719'}},
#  {'_index': 'users',
#   '_source': {'name': 'Abigail Maxwell',
#    'street': '3601 Novak Points',
#    'city': 'North Sylviamouth',
#    'zip': '01411'}},
#  {'_index': 'users',
#   '_source': {'name': 'Anthony Hammond',
#    'street': '554 Roth Spurs Apt. 054',
#    'city': 'Morenostad',
#    'zip': '02321'}},
#  {'_index': 'users',
#   '_source': {'name': 'John Chambers',
#    'street': '685 Armstrong Centers Apt. 630',
#    'city': 'Cardenaston',
#    'zip': '97882'}},
#  {'_index': 'users',
#   '_source': {'name': 'Dustin Clark',
#    'street': '5783 Noah Loop Suite 798',
#    'city': 'Alexanderland',
#    'zip': '06901'}},
#  {'_index': 'users',
#   '_source': {'name': 'Taylor Wilson',
#    'street': '6781 Hernandez Passage',
#    'city': 'Johnstonton',
#    'zip': '35171'}},
#  {'_index': 'users',
#   '_source': {'name': 'Matthew Shea',
#    'street': '42764 Berry Key Suite 895',
#    'city': 'Reedville',
#    'zip': '37081'}},
#  {'_index': 'users',
#   '_source': {'name': 'James Reynolds',
#    'street': '74454 Anthony Row',
#    'city': 'West Colleen',
#    'zip': '89024'}},
#  {'_index': 'users',
#   '_source': {'name': 'Chad Ferguson',
#    'street': '6591 Brooks Mount',
#    'city': 'Lopezland',
#    'zip': '82105'}},
#  {'_index': 'users',
#   '_source': {'name': 'Amanda Shepard',
#    'street': '9314 Lori Branch Apt. 412',
#    'city': 'East Keithfurt',
#    'zip': '28420'}},
#  {'_index': 'users',
#   '_source': {'name': 'Amber Trujillo',
#    'street': '170 Joseph Throughway Apt. 282',
#    'city': 'East Michael',
#    'zip': '36510'}},
#  {'_index': 'users',
#   '_source': {'name': 'Michael Collins',
#    'street': '779 Boone Oval Suite 432',
#    'city': 'Ayersmouth',
#    'zip': '77363'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mrs. Brenda Gardner',
#    'street': '5599 Timothy Neck Suite 821',
#    'city': 'West Joshua',
#    'zip': '21659'}},
#  {'_index': 'users',
#   '_source': {'name': 'Robert Williams',
#    'street': '156 Breanna Port Apt. 276',
#    'city': 'West Jessicaland',
#    'zip': '65477'}},
#  {'_index': 'users',
#   '_source': {'name': 'Sarah Washington',
#    'street': '876 Gonzalez Haven',
#    'city': 'Andrewside',
#    'zip': '57197'}},
#  {'_index': 'users',
#   '_source': {'name': 'Shawn Miller',
#    'street': '3166 William Keys',
#    'city': 'West Tammyburgh',
#    'zip': '83427'}},
#  {'_index': 'users',
#   '_source': {'name': 'Sharon Mcguire',
#    'street': '752 Wendy Streets',
#    'city': 'West Daniel',
#    'zip': '60230'}},
#  {'_index': 'users',
#   '_source': {'name': 'Holly Mills',
#    'street': '6448 Murphy Landing',
#    'city': 'Irwinside',
#    'zip': '17275'}},
#  {'_index': 'users',
#   '_source': {'name': 'Matthew Hoover',
#    'street': '1280 Williamson Ville',
#    'city': 'Lake Sean',
#    'zip': '74227'}},
#  {'_index': 'users',
#   '_source': {'name': 'Robert Taylor',
#    'street': '182 Johnson Radial',
#    'city': 'Walkerside',
#    'zip': '94209'}},
#  {'_index': 'users',
#   '_source': {'name': 'Robert Carpenter',
#    'street': '2311 Burch Turnpike',
#    'city': 'Carlsonberg',
#    'zip': '39812'}},
#  {'_index': 'users',
#   '_source': {'name': 'Emily Wong',
#    'street': '5279 Sanchez Center',
#    'city': 'New Emily',
#    'zip': '30329'}},
#  {'_index': 'users',
#   '_source': {'name': 'Miss Kayla Smith',
#    'street': '307 Jessica Manor Suite 412',
#    'city': 'New Phillip',
#    'zip': '71829'}},
#  {'_index': 'users',
#   '_source': {'name': 'Madison Conner',
#    'street': '280 Jacob Track Apt. 785',
#    'city': 'Amystad',
#    'zip': '40780'}},
#  {'_index': 'users',
#   '_source': {'name': 'David Wood',
#    'street': '31738 Charlene Rapid Suite 541',
#    'city': 'Contrerasberg',
#    'zip': '72845'}},
#  {'_index': 'users',
#   '_source': {'name': 'Joseph Holland',
#    'street': '30133 Susan Island',
#    'city': 'Danielfurt',
#    'zip': '12962'}},
#  {'_index': 'users',
#   '_source': {'name': 'Tanya Morales',
#    'street': '63076 Ann Light Apt. 126',
#    'city': 'Juarezfurt',
#    'zip': '48814'}},
#  {'_index': 'users',
#   '_source': {'name': 'Brian Jones',
#    'street': '566 Janet Course Suite 916',
#    'city': 'New Deborahport',
#    'zip': '34821'}},
#  {'_index': 'users',
#   '_source': {'name': 'William Santiago',
#    'street': '8404 Juan Canyon',
#    'city': 'South Kellymouth',
#    'zip': '02344'}},
#  {'_index': 'users',
#   '_source': {'name': 'Dana Young',
#    'street': '285 Andrew Locks Apt. 699',
#    'city': 'South Hollyhaven',
#    'zip': '85035'}},
#  {'_index': 'users',
#   '_source': {'name': 'Veronica Carson',
#    'street': '06981 Bautista Mountain',
#    'city': 'Lake Charles',
#    'zip': '43929'}},
#  {'_index': 'users',
#   '_source': {'name': 'Elaine Gregory',
#    'street': '1144 Robert Burg',
#    'city': 'South Geoffreyberg',
#    'zip': '59497'}},
#  {'_index': 'users',
#   '_source': {'name': 'Nicole Olson',
#    'street': '651 Williamson Key',
#    'city': 'Wrightport',
#    'zip': '64640'}},
#  {'_index': 'users',
#   '_source': {'name': 'Chad Lindsey',
#    'street': '17914 Sharon Trace',
#    'city': 'South Susan',
#    'zip': '04711'}},
#  {'_index': 'users',
#   '_source': {'name': 'Gail Bentley',
#    'street': '175 Ryan Mall',
#    'city': 'Careychester',
#    'zip': '22408'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jill Hinton',
#    'street': '656 Martin Oval Apt. 414',
#    'city': 'Moorestad',
#    'zip': '21852'}},
#  {'_index': 'users',
#   '_source': {'name': 'Shannon Flores',
#    'street': '7743 Robert Mission Suite 621',
#    'city': 'Castillotown',
#    'zip': '11765'}},
#  {'_index': 'users',
#   '_source': {'name': 'Monica Robinson',
#    'street': '943 Fischer Loaf Apt. 053',
#    'city': 'Ryanland',
#    'zip': '93232'}},
#  {'_index': 'users',
#   '_source': {'name': 'Danielle Brown',
#    'street': '9285 Mosley Tunnel Apt. 021',
#    'city': 'Lake Debbiehaven',
#    'zip': '86827'}},
#  {'_index': 'users',
#   '_source': {'name': 'Charles Moses',
#    'street': '48518 House Trafficway Apt. 944',
#    'city': 'Sarabury',
#    'zip': '93071'}},
#  {'_index': 'users',
#   '_source': {'name': 'Daniel Grant',
#    'street': '195 French Court',
#    'city': 'Duncanberg',
#    'zip': '76944'}},
#  {'_index': 'users',
#   '_source': {'name': 'Sharon Cole',
#    'street': '302 Miller Dale',
#    'city': 'Jenniferborough',
#    'zip': '34864'}},
#  {'_index': 'users',
#   '_source': {'name': 'Timothy Whitney',
#    'street': '046 Brown Tunnel Apt. 351',
#    'city': 'Brianville',
#    'zip': '22760'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jesse Morse',
#    'street': '80611 Steve Island Apt. 329',
#    'city': 'Brownhaven',
#    'zip': '62848'}},
#  {'_index': 'users',
#   '_source': {'name': 'Louis Walter',
#    'street': '224 Jacob Well Suite 830',
#    'city': 'Port Abigail',
#    'zip': '27475'}},
#  {'_index': 'users',
#   '_source': {'name': 'Lori Knight',
#    'street': '5148 Hall Rest',
#    'city': 'Greenstad',
#    'zip': '53800'}},
#  {'_index': 'users',
#   '_source': {'name': 'Thomas Fleming',
#    'street': '5165 Underwood Locks Suite 965',
#    'city': 'Michaelview',
#    'zip': '12905'}},
#  {'_index': 'users',
#   '_source': {'name': 'Alan Wall',
#    'street': '828 Jacob Point Apt. 171',
#    'city': 'Pamelaburgh',
#    'zip': '37100'}},
#  {'_index': 'users',
#   '_source': {'name': 'Christopher Ayala Jr.',
#    'street': '528 Jackson Keys Suite 293',
#    'city': 'South Elizabethfort',
#    'zip': '08906'}},
#  {'_index': 'users',
#   '_source': {'name': 'John Solis',
#    'street': '79162 Tracy Street',
#    'city': 'Rodriguezbury',
#    'zip': '92462'}},
#  {'_index': 'users',
#   '_source': {'name': 'Gerald Ho',
#    'street': '89479 Harding Lane',
#    'city': 'New Heidi',
#    'zip': '95480'}},
#  {'_index': 'users',
#   '_source': {'name': 'Michael Smith',
#    'street': '904 Wesley Parkway',
#    'city': 'Port Scott',
#    'zip': '17546'}},
#  {'_index': 'users',
#   '_source': {'name': 'Karen West',
#    'street': '815 Wilson Spurs Apt. 636',
#    'city': 'Tuckerville',
#    'zip': '97914'}},
#  {'_index': 'users',
#   '_source': {'name': 'Raymond Davis',
#    'street': '43279 Taylor Lodge Apt. 446',
#    'city': 'Leonardton',
#    'zip': '39055'}},
#  {'_index': 'users',
#   '_source': {'name': 'Theresa Boone MD',
#    'street': '73744 Erin Station Apt. 491',
#    'city': 'Priceview',
#    'zip': '51105'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kimberly Lindsey',
#    'street': '21663 Smith Hills Suite 541',
#    'city': 'Kimberlyborough',
#    'zip': '85890'}},
#  {'_index': 'users',
#   '_source': {'name': 'Patricia Keith',
#    'street': '1066 Osborne Ramp Suite 732',
#    'city': 'Washingtonville',
#    'zip': '58620'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jennifer Pope',
#    'street': '743 Boyle Plaza',
#    'city': 'Robertfurt',
#    'zip': '21754'}},
#  {'_index': 'users',
#   '_source': {'name': 'Leslie Martin',
#    'street': '551 Laura Crest Suite 457',
#    'city': 'Lake Tammieton',
#    'zip': '37813'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kristina Dean',
#    'street': '237 Amanda Drives',
#    'city': 'Port Leah',
#    'zip': '21705'}},
#  {'_index': 'users',
#   '_source': {'name': 'Justin Beard',
#    'street': '729 Scott Trace',
#    'city': 'Jenniferton',
#    'zip': '56241'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jeffrey Castillo',
#    'street': '189 Caitlin Extensions',
#    'city': 'Port Brandon',
#    'zip': '81076'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jerry Jordan',
#    'street': '38060 Jones Mountain Suite 178',
#    'city': 'Harperview',
#    'zip': '84142'}},
#  {'_index': 'users',
#   '_source': {'name': 'Sarah Hill',
#    'street': '05425 Jessica Corners Apt. 743',
#    'city': 'Lake Josephland',
#    'zip': '12307'}},
#  {'_index': 'users',
#   '_source': {'name': 'Adam Hernandez',
#    'street': '634 Black Dam',
#    'city': 'New Timothychester',
#    'zip': '28778'}},
#  {'_index': 'users',
#   '_source': {'name': 'Samuel Perry',
#    'street': '9551 Fowler Knoll',
#    'city': 'Briggsmouth',
#    'zip': '23284'}},
#  {'_index': 'users',
#   '_source': {'name': 'Andrew Thompson',
#    'street': '01505 Lisa Common Apt. 151',
#    'city': 'North Gavinshire',
#    'zip': '41536'}},
#  {'_index': 'users',
#   '_source': {'name': 'Felicia Martinez',
#    'street': '25403 Deanna Rest Apt. 582',
#    'city': 'North Douglas',
#    'zip': '01849'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jeffrey Erickson',
#    'street': '8034 William Summit',
#    'city': 'East Sabrinatown',
#    'zip': '87078'}},
#  {'_index': 'users',
#   '_source': {'name': 'Larry Wood',
#    'street': '6844 Garcia Locks Suite 348',
#    'city': 'New Davidshire',
#    'zip': '22676'}},
#  {'_index': 'users',
#   '_source': {'name': 'Raymond Wilson',
#    'street': '636 Elizabeth Mount',
#    'city': 'Robinsonborough',
#    'zip': '04094'}},
#  {'_index': 'users',
#   '_source': {'name': 'Dustin Haas',
#    'street': '08246 Christopher Junction',
#    'city': 'Boyerchester',
#    'zip': '40133'}},
#  {'_index': 'users',
#   '_source': {'name': 'Cindy Foster',
#    'street': '6436 Bauer Ramp Apt. 919',
#    'city': 'Gomezburgh',
#    'zip': '56155'}},
#  {'_index': 'users',
#   '_source': {'name': 'John Wise',
#    'street': '28688 Sierra Street Suite 522',
#    'city': 'South Dustinside',
#    'zip': '33699'}},
#  {'_index': 'users',
#   '_source': {'name': 'Tricia Woodard',
#    'street': '90880 Russo Row Apt. 827',
#    'city': 'East Richardtown',
#    'zip': '44011'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jacob Haas',
#    'street': '3684 Megan Manors',
#    'city': 'East Marissaville',
#    'zip': '36280'}},
#  {'_index': 'users',
#   '_source': {'name': 'Debra Johnson',
#    'street': '598 Nicholas Landing',
#    'city': 'Port Bonnie',
#    'zip': '83839'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kristen Perez',
#    'street': '14348 Patterson Meadows Apt. 941',
#    'city': 'Donovanhaven',
#    'zip': '45337'}},
#  {'_index': 'users',
#   '_source': {'name': 'Samantha Walsh',
#    'street': '76353 Patricia Lodge',
#    'city': 'Trevorland',
#    'zip': '49728'}},
#  {'_index': 'users',
#   '_source': {'name': 'Ebony Khan',
#    'street': '77596 Gabriel Way',
#    'city': 'West Crystalbury',
#    'zip': '52391'}},
#  {'_index': 'users',
#   '_source': {'name': 'Joshua Mccoy',
#    'street': '74531 Lutz Route Suite 036',
#    'city': 'Sullivanside',
#    'zip': '66935'}},
#  {'_index': 'users',
#   '_source': {'name': 'Gloria Price',
#    'street': '8680 Johnson Burgs',
#    'city': 'Willisside',
#    'zip': '29076'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mark Bush',
#    'street': '84608 Christopher Via Apt. 268',
#    'city': 'Christopherburgh',
#    'zip': '31414'}},
#  {'_index': 'users',
#   '_source': {'name': 'Brianna Carpenter',
#    'street': '406 Christopher Mall',
#    'city': 'Nicholasstad',
#    'zip': '46482'}},
#  {'_index': 'users',
#   '_source': {'name': 'Robert Rodriguez',
#    'street': '312 Lowe Flats Suite 904',
#    'city': 'North Christophermouth',
#    'zip': '27294'}},
#  {'_index': 'users',
#   '_source': {'name': 'Nancy Barnes',
#    'street': '230 Jerry Lodge Apt. 066',
#    'city': 'South David',
#    'zip': '27895'}},
#  {'_index': 'users',
#   '_source': {'name': 'Brian Nguyen',
#    'street': '170 Cody Fort Suite 433',
#    'city': 'North Pamela',
#    'zip': '34925'}},
#  {'_index': 'users',
#   '_source': {'name': 'Anna Williams',
#    'street': '566 Katelyn Court',
#    'city': 'Port Reginald',
#    'zip': '78438'}},
#  {'_index': 'users',
#   '_source': {'name': 'Keith Diaz',
#    'street': '877 Andrew Burg',
#    'city': 'Thompsonton',
#    'zip': '14812'}},
#  {'_index': 'users',
#   '_source': {'name': 'Michaela Morrison',
#    'street': '6148 Sheila Viaduct',
#    'city': 'South Jamesbury',
#    'zip': '58222'}},
#  {'_index': 'users',
#   '_source': {'name': 'Brian Diaz',
#    'street': '984 James Avenue Suite 373',
#    'city': 'West Barbarabury',
#    'zip': '96130'}},
#  {'_index': 'users',
#   '_source': {'name': 'Dawn Velez',
#    'street': '1021 Barbara Inlet',
#    'city': 'New Angelica',
#    'zip': '83222'}},
#  {'_index': 'users',
#   '_source': {'name': 'Dennis Valencia',
#    'street': '98228 Matthew Ridge',
#    'city': 'Michaelview',
#    'zip': '47875'}},
#  {'_index': 'users',
#   '_source': {'name': 'Dawn Ford',
#    'street': '50530 Kathryn Light Apt. 435',
#    'city': 'Garymouth',
#    'zip': '82776'}},
#  {'_index': 'users',
#   '_source': {'name': 'Samantha Nelson',
#    'street': '434 Salazar Valleys Suite 100',
#    'city': 'Kevinfurt',
#    'zip': '85844'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jose Cruz',
#    'street': '4682 David Course Apt. 811',
#    'city': 'Acostamouth',
#    'zip': '89956'}},
#  {'_index': 'users',
#   '_source': {'name': 'Tina Pitts',
#    'street': '93636 Theresa Hill',
#    'city': 'Haydentown',
#    'zip': '30338'}},
#  {'_index': 'users',
#   '_source': {'name': 'Joseph Lee',
#    'street': '7112 Ingram Ford Apt. 114',
#    'city': 'Ryanborough',
#    'zip': '29087'}},
#  {'_index': 'users',
#   '_source': {'name': 'Randall Wright',
#    'street': '444 Reese Knoll',
#    'city': 'Olivertown',
#    'zip': '01035'}},
#  {'_index': 'users',
#   '_source': {'name': 'Dave Foster',
#    'street': '207 Edwards Streets Apt. 677',
#    'city': 'Port Caitlin',
#    'zip': '35277'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mr. John Harper',
#    'street': '715 Clifford Via Suite 069',
#    'city': 'Port Rickymouth',
#    'zip': '22855'}},
#  {'_index': 'users',
#   '_source': {'name': 'Joshua Castillo',
#    'street': '583 Darryl Estate Apt. 078',
#    'city': 'Bennettmouth',
#    'zip': '46838'}},
#  {'_index': 'users',
#   '_source': {'name': 'Andrea Woods',
#    'street': '82210 Angela Run',
#    'city': 'West Samantha',
#    'zip': '13426'}},
#  {'_index': 'users',
#   '_source': {'name': 'Christian Thornton',
#    'street': '026 Lopez Extension Suite 232',
#    'city': 'Port Jessica',
#    'zip': '47556'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kathryn Newton',
#    'street': '35169 Carrie Mews',
#    'city': 'Jonchester',
#    'zip': '33112'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jasmine Sullivan',
#    'street': '09417 Webster Viaduct Apt. 546',
#    'city': 'Thomasburgh',
#    'zip': '68573'}},
#  {'_index': 'users',
#   '_source': {'name': 'Alan Phillips',
#    'street': '007 Phillips Brook',
#    'city': 'East Tanyaberg',
#    'zip': '62355'}},
#  {'_index': 'users',
#   '_source': {'name': 'Phyllis Hernandez',
#    'street': '725 Raymond Tunnel',
#    'city': 'Kellerstad',
#    'zip': '55559'}},
#  {'_index': 'users',
#   '_source': {'name': 'Lauren Moore',
#    'street': '14501 Butler Pike Suite 097',
#    'city': 'West Anthonymouth',
#    'zip': '76063'}},
#  {'_index': 'users',
#   '_source': {'name': 'Clifford Gonzalez',
#    'street': '199 Brooks Unions Apt. 488',
#    'city': 'North Dominic',
#    'zip': '41467'}},
#  {'_index': 'users',
#   '_source': {'name': 'Charles Davidson',
#    'street': '35075 Wendy Hills Apt. 333',
#    'city': 'Davidburgh',
#    'zip': '96766'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kelly Henderson',
#    'street': '26587 Flores Trace',
#    'city': 'New Angela',
#    'zip': '23259'}},
#  {'_index': 'users',
#   '_source': {'name': 'Ashley Martinez',
#    'street': '583 Wilson Parks',
#    'city': 'West Nicholasberg',
#    'zip': '48762'}},
#  {'_index': 'users',
#   '_source': {'name': 'Brenda Wright',
#    'street': '387 Allison Row Apt. 714',
#    'city': 'Lake Sarashire',
#    'zip': '52959'}},
#  {'_index': 'users',
#   '_source': {'name': 'Tracey Jennings',
#    'street': '51555 Taylor Manor',
#    'city': 'Port Scott',
#    'zip': '14529'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mark Ruiz',
#    'street': '532 William Lock Suite 362',
#    'city': 'Archermouth',
#    'zip': '83746'}},
#  {'_index': 'users',
#   '_source': {'name': 'Devin Mckenzie',
#    'street': '7794 Smith Bridge',
#    'city': 'Robinsonport',
#    'zip': '78453'}},
#  {'_index': 'users',
#   '_source': {'name': 'Ashley Wood',
#    'street': '7005 Wolf Junction Apt. 997',
#    'city': 'West Heather',
#    'zip': '53622'}},
#  {'_index': 'users',
#   '_source': {'name': 'Marissa Myers',
#    'street': '0232 Terrell Groves Suite 358',
#    'city': 'North Juanstad',
#    'zip': '14054'}},
#  {'_index': 'users',
#   '_source': {'name': 'Marvin Benton',
#    'street': '496 Medina Port',
#    'city': 'South Joshuahaven',
#    'zip': '93523'}},
#  {'_index': 'users',
#   '_source': {'name': 'Adam Foster',
#    'street': '974 Boyer Green',
#    'city': 'Warrenmouth',
#    'zip': '63950'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jerry Smith',
#    'street': '4449 Heather Row',
#    'city': 'Angelatown',
#    'zip': '29777'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mikayla Rios',
#    'street': '183 Eric Pine Suite 938',
#    'city': 'Troyton',
#    'zip': '92381'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kathleen Phelps',
#    'street': '34972 Webb Rue',
#    'city': 'West James',
#    'zip': '24304'}},
#  {'_index': 'users',
#   '_source': {'name': 'Casey Green',
#    'street': '58213 Fernandez Crossing Suite 521',
#    'city': 'Ryanmouth',
#    'zip': '88967'}},
#  {'_index': 'users',
#   '_source': {'name': 'Angela Thompson',
#    'street': '55455 White Views Suite 643',
#    'city': 'East Amychester',
#    'zip': '72506'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kaitlyn Miller',
#    'street': '28387 Tiffany Prairie',
#    'city': 'Masonborough',
#    'zip': '30760'}},
#  {'_index': 'users',
#   '_source': {'name': 'Hailey Hood',
#    'street': '257 Brandon Ports Suite 722',
#    'city': 'East Franciscoland',
#    'zip': '11975'}},
#  {'_index': 'users',
#   '_source': {'name': 'James Smith DVM',
#    'street': '9270 Peter Pike Apt. 921',
#    'city': 'West Matthew',
#    'zip': '19832'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jamie Riley',
#    'street': '8126 Skinner Inlet Apt. 922',
#    'city': 'North Seantown',
#    'zip': '54290'}},
#  {'_index': 'users',
#   '_source': {'name': 'Robert Lynch',
#    'street': '5723 Tony Lane',
#    'city': 'Andersonburgh',
#    'zip': '63011'}},
#  {'_index': 'users',
#   '_source': {'name': 'Travis Rivera',
#    'street': '95732 Crystal Mill',
#    'city': 'North Jamesborough',
#    'zip': '99704'}},
#  {'_index': 'users',
#   '_source': {'name': 'Lisa Anderson',
#    'street': '90860 Hawkins Plains Apt. 231',
#    'city': 'South Joelmouth',
#    'zip': '03577'}},
#  {'_index': 'users',
#   '_source': {'name': 'Roy Wright',
#    'street': '631 Watts Village',
#    'city': 'South Lauren',
#    'zip': '46769'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jessica Pearson',
#    'street': '74566 Emily Mission',
#    'city': 'Port Robinfurt',
#    'zip': '29728'}},
#  {'_index': 'users',
#   '_source': {'name': 'Melinda Mcpherson',
#    'street': '6071 David Parks',
#    'city': 'East Nataliemouth',
#    'zip': '10845'}},
#  {'_index': 'users',
#   '_source': {'name': 'Erin White',
#    'street': '157 Smith Village Suite 035',
#    'city': 'Davisbury',
#    'zip': '60259'}},
#  {'_index': 'users',
#   '_source': {'name': 'David Becker',
#    'street': '29536 Samantha Creek Apt. 713',
#    'city': 'Michaelview',
#    'zip': '81659'}},
#  {'_index': 'users',
#   '_source': {'name': 'Nicole Young',
#    'street': '43946 Gates Extension Apt. 566',
#    'city': 'Robertoport',
#    'zip': '98931'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mrs. Christy Hunter MD',
#    'street': '93739 Figueroa Meadow',
#    'city': 'Samuelview',
#    'zip': '51298'}},
#  {'_index': 'users',
#   '_source': {'name': 'Christine Gutierrez DVM',
#    'street': '465 Todd Corners',
#    'city': 'West Lauren',
#    'zip': '64291'}},
#  {'_index': 'users',
#   '_source': {'name': 'Rose Schmidt',
#    'street': '692 William Gateway Apt. 766',
#    'city': 'New Jeffrey',
#    'zip': '41154'}},
#  {'_index': 'users',
#   '_source': {'name': 'Brian Hanson',
#    'street': '741 Gonzales Crest Suite 090',
#    'city': 'South Sara',
#    'zip': '67501'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jessica Cooper',
#    'street': '690 Sheila Glens Suite 140',
#    'city': 'Hicksfurt',
#    'zip': '44385'}},
#  {'_index': 'users',
#   '_source': {'name': 'Patrick Carney',
#    'street': '1482 Torres Point',
#    'city': 'East Lisa',
#    'zip': '58675'}},
#  {'_index': 'users',
#   '_source': {'name': 'James Jackson',
#    'street': '5250 Shannon Corners',
#    'city': 'New Christopher',
#    'zip': '52658'}},
#  {'_index': 'users',
#   '_source': {'name': 'Stephanie Freeman',
#    'street': '23054 Cody Mountains',
#    'city': 'Hallshire',
#    'zip': '34183'}},
#  {'_index': 'users',
#   '_source': {'name': 'Brendan Smith',
#    'street': '93809 Sara Common Suite 550',
#    'city': 'West Kimberlyberg',
#    'zip': '59381'}},
#  {'_index': 'users',
#   '_source': {'name': 'Patricia Curtis',
#    'street': '8790 Rebecca Prairie',
#    'city': 'South Kimberlyborough',
#    'zip': '43525'}},
#  {'_index': 'users',
#   '_source': {'name': 'Linda Harris',
#    'street': '3619 David Brook',
#    'city': 'West Andrea',
#    'zip': '43785'}},
#  {'_index': 'users',
#   '_source': {'name': 'Lindsay Turner',
#    'street': '13568 Chandler Ridge',
#    'city': 'Solismouth',
#    'zip': '49766'}},
#  {'_index': 'users',
#   '_source': {'name': 'Angela West',
#    'street': '68258 Lamb Groves',
#    'city': 'South Josephbury',
#    'zip': '11856'}},
#  {'_index': 'users',
#   '_source': {'name': 'Angie Schmidt',
#    'street': '4132 Valenzuela Green',
#    'city': 'Robertshire',
#    'zip': '75073'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jessica Barnes',
#    'street': '107 Donna Dam',
#    'city': 'South Willie',
#    'zip': '49861'}},
#  {'_index': 'users',
#   '_source': {'name': 'Laura Phillips',
#    'street': '3253 Thomas Shores Suite 928',
#    'city': 'New Ivanfurt',
#    'zip': '77223'}},
#  {'_index': 'users',
#   '_source': {'name': 'Phillip Johnston',
#    'street': '765 William Knolls',
#    'city': 'Roseberg',
#    'zip': '59359'}},
#  {'_index': 'users',
#   '_source': {'name': 'Christina Anderson',
#    'street': '971 Krystal Fields',
#    'city': 'East Katherinetown',
#    'zip': '02566'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jonathan Henry',
#    'street': '94637 Keith Lane Suite 242',
#    'city': 'North Christopher',
#    'zip': '07105'}},
#  {'_index': 'users',
#   '_source': {'name': 'Ryan Wright',
#    'street': '5523 Wright Harbor',
#    'city': 'Robinside',
#    'zip': '42288'}},
#  {'_index': 'users',
#   '_source': {'name': 'Shannon Gonzales',
#    'street': '6866 Ashley Greens Apt. 140',
#    'city': 'New Alyssachester',
#    'zip': '70594'}},
#  {'_index': 'users',
#   '_source': {'name': 'Cory Turner',
#    'street': '22867 Tricia Prairie Apt. 457',
#    'city': 'Glennchester',
#    'zip': '67037'}},
#  {'_index': 'users',
#   '_source': {'name': 'Allen Pierce',
#    'street': '7969 Willis Terrace Apt. 357',
#    'city': 'Christopherchester',
#    'zip': '67849'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mark Henson',
#    'street': '7783 Reyes Trace',
#    'city': 'East Deborahshire',
#    'zip': '21547'}},
#  {'_index': 'users',
#   '_source': {'name': 'Thomas Leblanc',
#    'street': '0784 Darrell Course',
#    'city': 'Arnoldside',
#    'zip': '08243'}},
#  {'_index': 'users',
#   '_source': {'name': 'Stephanie Jackson',
#    'street': '576 Brady Divide Apt. 985',
#    'city': 'West Jennifer',
#    'zip': '26951'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jeremiah Brown',
#    'street': '84593 Sue Mission Suite 042',
#    'city': 'Bestmouth',
#    'zip': '81572'}},
#  {'_index': 'users',
#   '_source': {'name': 'Eduardo Franco',
#    'street': '56087 Joshua Harbors',
#    'city': 'North Shannon',
#    'zip': '87134'}},
#  {'_index': 'users',
#   '_source': {'name': 'Richard Wood',
#    'street': '8808 Stephanie Curve',
#    'city': 'New Jamesmouth',
#    'zip': '57178'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jamie Smith',
#    'street': '39194 Avila Overpass',
#    'city': 'South Tamaramouth',
#    'zip': '27464'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mark Garcia',
#    'street': '228 Amy Course',
#    'city': 'Brittanyport',
#    'zip': '71757'}},
#  {'_index': 'users',
#   '_source': {'name': 'Joshua Gates',
#    'street': '7148 Brown Centers Apt. 458',
#    'city': 'Lake Jillian',
#    'zip': '34698'}},
#  {'_index': 'users',
#   '_source': {'name': 'Stacey Diaz',
#    'street': '7583 Hector Roads Suite 581',
#    'city': 'Lake Jeffreybury',
#    'zip': '13665'}},
#  {'_index': 'users',
#   '_source': {'name': 'Roger Gonzalez',
#    'street': '77425 Baldwin Square Apt. 996',
#    'city': 'Lake Tonyfurt',
#    'zip': '47041'}},
#  {'_index': 'users',
#   '_source': {'name': 'Alexander Harding',
#    'street': '7178 Wilson Hills Apt. 516',
#    'city': 'East Ryanmouth',
#    'zip': '25076'}},
#  {'_index': 'users',
#   '_source': {'name': 'Phillip Thomas',
#    'street': '238 Sherry Haven',
#    'city': 'Lake Josephtown',
#    'zip': '99450'}},
#  {'_index': 'users',
#   '_source': {'name': 'Richard Hall',
#    'street': '079 Mann Harbors Apt. 270',
#    'city': 'Port Jade',
#    'zip': '28831'}},
#  {'_index': 'users',
#   '_source': {'name': 'Christopher Johnson',
#    'street': '028 Hendrix Center',
#    'city': 'Kristytown',
#    'zip': '41979'}},
#  {'_index': 'users',
#   '_source': {'name': 'James Sanchez',
#    'street': '8319 George Forges Apt. 699',
#    'city': 'Lake Heatherside',
#    'zip': '61096'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kelly Johnson',
#    'street': '755 Lee Mount',
#    'city': 'Lake Nicoleton',
#    'zip': '11268'}},
#  {'_index': 'users',
#   '_source': {'name': 'Cassandra Greer',
#    'street': '624 Jones Gardens',
#    'city': 'North Brian',
#    'zip': '34906'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jorge Fernandez',
#    'street': '978 Nathan Springs Apt. 498',
#    'city': 'New Patrickchester',
#    'zip': '34721'}},
#  {'_index': 'users',
#   '_source': {'name': 'Curtis Murphy',
#    'street': '6653 Tiffany Burg Apt. 099',
#    'city': 'North Jonathan',
#    'zip': '62812'}},
#  {'_index': 'users',
#   '_source': {'name': 'Gregory Hammond',
#    'street': '4489 Jason Shoal',
#    'city': 'Port Brittany',
#    'zip': '73470'}},
#  {'_index': 'users',
#   '_source': {'name': 'Victoria Aguilar',
#    'street': '580 Ward Trafficway',
#    'city': 'North Richardland',
#    'zip': '21737'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kyle Wright',
#    'street': '203 Norton Trace Apt. 759',
#    'city': 'East Amanda',
#    'zip': '71440'}},
#  {'_index': 'users',
#   '_source': {'name': 'Johnathan Norris',
#    'street': '601 Kathleen Brooks Suite 563',
#    'city': 'West Rebeccastad',
#    'zip': '64220'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kevin Moore',
#    'street': '8183 Carol Hollow',
#    'city': 'Johnberg',
#    'zip': '08989'}},
#  {'_index': 'users',
#   '_source': {'name': 'Susan Reed',
#    'street': '2382 Cunningham Underpass Apt. 340',
#    'city': 'Rosariomouth',
#    'zip': '97286'}},
#  {'_index': 'users',
#   '_source': {'name': 'Nicole Armstrong',
#    'street': '368 Sheila Stream',
#    'city': 'New Randychester',
#    'zip': '71472'}},
#  {'_index': 'users',
#   '_source': {'name': 'Michael Barron',
#    'street': '441 Lisa Cliffs',
#    'city': 'Garytown',
#    'zip': '40431'}},
#  {'_index': 'users',
#   '_source': {'name': 'Stephanie Davila',
#    'street': '8437 Tina Road',
#    'city': 'Brownton',
#    'zip': '82041'}},
#  {'_index': 'users',
#   '_source': {'name': 'Amanda Thomas',
#    'street': '457 Reed Summit',
#    'city': 'Jeffreymouth',
#    'zip': '30562'}},
#  {'_index': 'users',
#   '_source': {'name': 'Cynthia Sanchez',
#    'street': '68398 Trevor Club',
#    'city': 'North Kendra',
#    'zip': '76949'}},
#  {'_index': 'users',
#   '_source': {'name': 'Lisa Wagner',
#    'street': '034 Edward Plains',
#    'city': 'Cortezshire',
#    'zip': '35271'}},
#  {'_index': 'users',
#   '_source': {'name': 'Emily Galvan',
#    'street': '943 Wells Street',
#    'city': 'West Davidburgh',
#    'zip': '52248'}},
#  {'_index': 'users',
#   '_source': {'name': 'James Townsend',
#    'street': '64691 Thompson Inlet',
#    'city': 'Samanthaburgh',
#    'zip': '76742'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mrs. Theresa Hunter',
#    'street': '549 Gutierrez Mount Apt. 617',
#    'city': 'Johntown',
#    'zip': '10855'}},
#  {'_index': 'users',
#   '_source': {'name': 'Vanessa Franklin',
#    'street': '8311 Williams Cliff',
#    'city': 'Lake Andrewbury',
#    'zip': '98058'}},
#  {'_index': 'users',
#   '_source': {'name': 'Alexis Rogers',
#    'street': '074 Thompson Dale Suite 919',
#    'city': 'South Jason',
#    'zip': '97750'}},
#  {'_index': 'users',
#   '_source': {'name': 'Monique Rogers',
#    'street': '87973 Ashley River Apt. 064',
#    'city': 'Davisport',
#    'zip': '21508'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kevin Montes',
#    'street': '752 Joshua Overpass Suite 076',
#    'city': 'Sparksborough',
#    'zip': '36221'}},
#  {'_index': 'users',
#   '_source': {'name': 'Dr. Jennifer Kemp',
#    'street': '4010 Stone Plain',
#    'city': 'North Courtney',
#    'zip': '42952'}},
#  {'_index': 'users',
#   '_source': {'name': 'Robin Gordon',
#    'street': '51417 Grant Parkways Apt. 666',
#    'city': 'North Sandyborough',
#    'zip': '11643'}},
#  {'_index': 'users',
#   '_source': {'name': 'Adrian Robinson',
#    'street': '419 James Orchard Apt. 186',
#    'city': 'Emilyton',
#    'zip': '17759'}},
#  {'_index': 'users',
#   '_source': {'name': 'Stacy Snyder',
#    'street': '98680 Cole Causeway',
#    'city': 'New Matthewmouth',
#    'zip': '50802'}},
#  {'_index': 'users',
#   '_source': {'name': 'Brian Mejia',
#    'street': '759 Kane Pine',
#    'city': 'Richardsonfurt',
#    'zip': '47505'}},
#  {'_index': 'users',
#   '_source': {'name': 'Haley Fernandez',
#    'street': '280 Wagner Burgs',
#    'city': 'Port Jamesmouth',
#    'zip': '43314'}},
#  {'_index': 'users',
#   '_source': {'name': 'Gregory Matthews',
#    'street': '47504 Garrett Springs Suite 138',
#    'city': 'North Madisonbury',
#    'zip': '86349'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jon Mcgee',
#    'street': '78081 Wilson Garden',
#    'city': 'Nathanstad',
#    'zip': '24301'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jocelyn Gibson',
#    'street': '807 Suzanne Crescent',
#    'city': 'Matthewstad',
#    'zip': '72023'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kenneth Buchanan',
#    'street': '7916 Derek Mews',
#    'city': 'Jamesberg',
#    'zip': '41495'}},
#  {'_index': 'users',
#   '_source': {'name': 'Deborah Rodriguez',
#    'street': '3270 Richards Meadow',
#    'city': 'Cookmouth',
#    'zip': '47013'}},
#  {'_index': 'users',
#   '_source': {'name': 'Chelsea Watkins',
#    'street': '827 Williams Row',
#    'city': 'Harveystad',
#    'zip': '10501'}},
#  {'_index': 'users',
#   '_source': {'name': 'Timothy Estes',
#    'street': '546 Lori Meadows Suite 906',
#    'city': 'Laurastad',
#    'zip': '85341'}},
#  {'_index': 'users',
#   '_source': {'name': 'Katherine Rogers',
#    'street': '471 Kenneth Ports Apt. 752',
#    'city': 'Brandyville',
#    'zip': '59627'}},
#  {'_index': 'users',
#   '_source': {'name': 'Tiffany Jackson',
#    'street': '94343 Jason Dam Suite 652',
#    'city': 'West Brianna',
#    'zip': '16212'}},
#  {'_index': 'users',
#   '_source': {'name': 'Wendy Williams',
#    'street': '9609 Welch Throughway',
#    'city': 'Christianstad',
#    'zip': '93385'}},
#  {'_index': 'users',
#   '_source': {'name': 'Brianna Murphy',
#    'street': '19424 Jessica Plains',
#    'city': 'South Jonathanhaven',
#    'zip': '25848'}},
#  {'_index': 'users',
#   '_source': {'name': 'Monica Lucas',
#    'street': '61260 Villa Station Suite 670',
#    'city': 'Lake Stephen',
#    'zip': '34468'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jessica Brown',
#    'street': '9905 Travis Prairie Suite 421',
#    'city': 'Samanthaville',
#    'zip': '32739'}},
#  {'_index': 'users',
#   '_source': {'name': 'Adam Thomas',
#    'street': '744 Goodwin Lodge',
#    'city': 'East Sean',
#    'zip': '49224'}},
#  {'_index': 'users',
#   '_source': {'name': 'Richard Reyes',
#    'street': '2657 Adams Harbor',
#    'city': 'West Tracy',
#    'zip': '49451'}},
#  {'_index': 'users',
#   '_source': {'name': 'Hannah Phelps',
#    'street': '137 Patterson Lodge Suite 403',
#    'city': 'West Melissa',
#    'zip': '95502'}},
#  {'_index': 'users',
#   '_source': {'name': 'Michael Carter',
#    'street': '3300 Haley Wells Suite 003',
#    'city': 'South Sandra',
#    'zip': '88920'}},
#  {'_index': 'users',
#   '_source': {'name': 'Samantha Chavez',
#    'street': '135 Macdonald Trail',
#    'city': 'Martinberg',
#    'zip': '72693'}},
#  {'_index': 'users',
#   '_source': {'name': 'Dr. Noah Frey',
#    'street': '525 April Mountain',
#    'city': 'North Saraland',
#    'zip': '19406'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mario Nelson',
#    'street': '590 Kathleen Key Apt. 288',
#    'city': 'Alexandraberg',
#    'zip': '25214'}},
#  {'_index': 'users',
#   '_source': {'name': 'Maria Morrison',
#    'street': '453 Michael Circles',
#    'city': 'East Samantha',
#    'zip': '17754'}},
#  {'_index': 'users',
#   '_source': {'name': 'Brian Summers',
#    'street': '6002 Kristine Prairie Apt. 436',
#    'city': 'East Jonathanside',
#    'zip': '71468'}},
#  {'_index': 'users',
#   '_source': {'name': 'Edward Powell',
#    'street': '68319 Daniel Motorway',
#    'city': 'Kennethmouth',
#    'zip': '44240'}},
#  {'_index': 'users',
#   '_source': {'name': 'Bill Taylor',
#    'street': '6731 Anthony Pass',
#    'city': 'Crosbymouth',
#    'zip': '86118'}},
#  {'_index': 'users',
#   '_source': {'name': 'Shannon Rodriguez',
#    'street': '73854 Hawkins Bridge',
#    'city': 'Hoport',
#    'zip': '87746'}},
#  {'_index': 'users',
#   '_source': {'name': 'Dennis Long',
#    'street': '468 Joseph Underpass',
#    'city': 'West Amandaland',
#    'zip': '64771'}},
#  {'_index': 'users',
#   '_source': {'name': 'Daniel Kennedy',
#    'street': '6492 Liu Trail',
#    'city': 'North Patriciamouth',
#    'zip': '62152'}},
#  {'_index': 'users',
#   '_source': {'name': 'Christopher Bennett',
#    'street': '70795 Lucas Fords',
#    'city': 'Davidville',
#    'zip': '94790'}},
#  {'_index': 'users',
#   '_source': {'name': 'Trevor Herrera',
#    'street': '30451 Christina Route Apt. 058',
#    'city': 'South Davidland',
#    'zip': '30649'}},
#  {'_index': 'users',
#   '_source': {'name': 'Peter Armstrong',
#    'street': '23472 Bradford Trafficway',
#    'city': 'East Roger',
#    'zip': '33077'}},
#  {'_index': 'users',
#   '_source': {'name': 'James White',
#    'street': '912 Norton Trail',
#    'city': 'North Robintown',
#    'zip': '37552'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jamie Green',
#    'street': '9006 Thompson Canyon',
#    'city': 'Davisport',
#    'zip': '33682'}},
#  {'_index': 'users',
#   '_source': {'name': 'William Morris',
#    'street': '431 Foster Road Apt. 309',
#    'city': 'Devontown',
#    'zip': '11759'}},
#  {'_index': 'users',
#   '_source': {'name': 'Ashley Nolan',
#    'street': '312 Hickman Mountains Apt. 078',
#    'city': 'Sanchezfort',
#    'zip': '60119'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jorge Bender',
#    'street': '42068 Johnson Ferry Suite 521',
#    'city': 'West Johnburgh',
#    'zip': '02727'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jerry Coleman',
#    'street': '491 Murphy Motorway Suite 600',
#    'city': 'Carlosmouth',
#    'zip': '83415'}},
#  {'_index': 'users',
#   '_source': {'name': 'Ashley Lambert',
#    'street': '6751 Griffith Avenue',
#    'city': 'Anthonymouth',
#    'zip': '53238'}},
#  {'_index': 'users',
#   '_source': {'name': 'Karla Wood',
#    'street': '6108 Brewer Plaza',
#    'city': 'South Phillipbury',
#    'zip': '94806'}},
#  {'_index': 'users',
#   '_source': {'name': 'James Hall',
#    'street': '764 Jennifer Estates Suite 033',
#    'city': 'Lake Colleenborough',
#    'zip': '52423'}},
#  {'_index': 'users',
#   '_source': {'name': 'Raymond Stewart',
#    'street': '9673 Gabriel Greens Apt. 987',
#    'city': 'Parksbury',
#    'zip': '25237'}},
#  {'_index': 'users',
#   '_source': {'name': 'Christopher Goodman',
#    'street': '348 Tran Square Apt. 042',
#    'city': 'Lake Codyburgh',
#    'zip': '08992'}},
#  {'_index': 'users',
#   '_source': {'name': 'Carlos Murphy',
#    'street': '173 Kristin Meadows',
#    'city': 'Craigstad',
#    'zip': '96480'}},
#  {'_index': 'users',
#   '_source': {'name': 'Daniel Pennington',
#    'street': '745 Holland Hill',
#    'city': 'West Kara',
#    'zip': '18350'}},
#  {'_index': 'users',
#   '_source': {'name': 'Tracy Flores PhD',
#    'street': '383 Steve Stream',
#    'city': 'Jenniferberg',
#    'zip': '30719'}},
#  {'_index': 'users',
#   '_source': {'name': 'Renee Flores',
#    'street': '55905 Palmer Tunnel Apt. 583',
#    'city': 'North Scottmouth',
#    'zip': '62666'}},
#  {'_index': 'users',
#   '_source': {'name': 'Gabrielle King',
#    'street': '4206 Amy Highway Apt. 558',
#    'city': 'New Tony',
#    'zip': '04715'}},
#  {'_index': 'users',
#   '_source': {'name': 'Anthony Perry',
#    'street': '056 Jessica Ville Suite 564',
#    'city': 'Port Sharon',
#    'zip': '23603'}},
#  {'_index': 'users',
#   '_source': {'name': 'Sean Obrien',
#    'street': '0801 Ashley Hollow',
#    'city': 'New Wesley',
#    'zip': '10088'}},
#  {'_index': 'users',
#   '_source': {'name': 'Ryan Nelson',
#    'street': '740 Moore Station',
#    'city': 'Smithside',
#    'zip': '89759'}},
#  {'_index': 'users',
#   '_source': {'name': 'Samantha Armstrong',
#    'street': '563 Douglas Mills',
#    'city': 'Carolhaven',
#    'zip': '30276'}},
#  {'_index': 'users',
#   '_source': {'name': 'Corey Miller',
#    'street': '2122 Joseph Path Suite 782',
#    'city': 'Port Veronica',
#    'zip': '14934'}},
#  {'_index': 'users',
#   '_source': {'name': 'Antonio Miller',
# ...
#    'street': '655 Scott Route Suite 547',
#    'city': 'East Michael',
#    'zip': '63678'}},
#  {'_index': 'users',
#   '_source': {'name': 'Deborah Swanson',
#    'street': '89307 Dalton Lodge Apt. 240',
#    'city': 'Mitchelltown',
#    'zip': '12565'}},
#  {'_index': 'users',
#   '_source': {'name': 'Katherine Perez',
#    'street': '3868 Jennings Light Apt. 586',
#    'city': 'Isaacside',
#    'zip': '56243'}},
#  {'_index': 'users',
#   '_source': {'name': 'James Moore',
#    'street': '41672 Miller Station Apt. 883',
#    'city': 'North Michelle',
#    'zip': '34302'}},
#  {'_index': 'users',
#   '_source': {'name': 'Courtney Patterson',
#    'street': '83915 Julia Row Suite 345',
#    'city': 'Lake Manuel',
#    'zip': '27028'}},
#  {'_index': 'users',
#   '_source': {'name': 'Melissa Robbins',
#    'street': '76398 Williams Turnpike',
#    'city': 'New Brittany',
#    'zip': '46149'}},
#  {'_index': 'users',
#   '_source': {'name': 'Russell Brooks',
#    'street': '09074 Sanchez Burg Apt. 454',
#    'city': 'South Christopherland',
#    'zip': '03996'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kelly Davis',
#    'street': '314 Nichols Turnpike',
#    'city': 'West Loriburgh',
#    'zip': '30123'}},
#  {'_index': 'users',
#   '_source': {'name': 'Justin Wood',
#    'street': '143 Kathryn Views',
#    'city': 'South Reginald',
#    'zip': '29312'}},
#  {'_index': 'users',
#   '_source': {'name': 'Lindsey Moore',
#    'street': '431 Joshua Ranch Suite 502',
#    'city': 'Laurabury',
#    'zip': '51250'}},
#  {'_index': 'users',
#   '_source': {'name': 'Rebecca Davis',
#    'street': '66388 Melanie Extensions Apt. 518',
#    'city': 'Allisonport',
#    'zip': '17534'}},
#  {'_index': 'users',
#   '_source': {'name': 'Lauren Powell',
#    'street': '09803 Novak Cliff',
#    'city': 'East Andrea',
#    'zip': '60207'}},
#  {'_index': 'users',
#   '_source': {'name': 'Wesley Gilmore',
#    'street': '293 Castillo Station Suite 212',
#    'city': 'West Aliciaport',
#    'zip': '37463'}},
#  {'_index': 'users',
#   '_source': {'name': 'Robert Blackburn',
#    'street': '530 Monica Trail',
#    'city': 'Jesseport',
#    'zip': '65617'}},
#  {'_index': 'users',
#   '_source': {'name': 'Gregory Wright',
#    'street': '599 Austin Key',
#    'city': 'Lake Deborahfurt',
#    'zip': '02346'}},
#  {'_index': 'users',
#   '_source': {'name': 'Heather Smith',
#    'street': '3916 Brandon Street Suite 184',
#    'city': 'East Catherineton',
#    'zip': '68070'}},
#  {'_index': 'users',
#   '_source': {'name': 'Angelica Rosales',
#    'street': '9564 Peters Centers',
#    'city': 'Port Charlene',
#    'zip': '13840'}},
#  {'_index': 'users',
#   '_source': {'name': 'Arthur Green',
#    'street': '96018 Judith Track Suite 189',
#    'city': 'Tylerberg',
#    'zip': '30862'}},
#  {'_index': 'users',
#   '_source': {'name': 'Marc Jones',
#    'street': '7528 Sara Throughway Apt. 769',
#    'city': 'Kellyville',
#    'zip': '09657'}},
#  {'_index': 'users',
#   '_source': {'name': 'James Chase',
#    'street': '5629 Smith Mount Apt. 554',
#    'city': 'North James',
#    'zip': '19290'}},
#  {'_index': 'users',
#   '_source': {'name': 'Lindsay Wolfe',
#    'street': '4825 Kelly Stream',
#    'city': 'North Matthewmouth',
#    'zip': '27678'}},
#  {'_index': 'users',
#   '_source': {'name': 'Francisco Obrien',
#    'street': '217 Mcconnell Spring Suite 957',
#    'city': 'Port Darrenberg',
#    'zip': '13388'}},
#  {'_index': 'users',
#   '_source': {'name': 'Bradley Shaw',
#    'street': '87818 George Lodge',
#    'city': 'Clineport',
#    'zip': '72527'}},
#  {'_index': 'users',
#   '_source': {'name': 'Virginia Evans',
#    'street': '47221 Ashley Loop',
#    'city': 'Port Annaland',
#    'zip': '34179'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jordan Rivera',
#    'street': '95368 Williams Landing',
#    'city': 'Paulfort',
#    'zip': '39179'}},
#  {'_index': 'users',
#   '_source': {'name': 'Julia James',
#    'street': '1632 Stewart Fall Suite 724',
#    'city': 'Lake Madison',
#    'zip': '57303'}},
#  {'_index': 'users',
#   '_source': {'name': 'Deborah Rice',
#    'street': '2591 Jeffrey Valley Apt. 938',
#    'city': 'Martinshire',
#    'zip': '83379'}},
#  {'_index': 'users',
#   '_source': {'name': 'Cynthia Jacobson',
#    'street': '651 Gilmore Drives',
#    'city': 'South Ronald',
#    'zip': '43275'}},
#  {'_index': 'users',
#   '_source': {'name': 'Rebecca Davis',
#    'street': '93952 Alexander Parks Suite 585',
#    'city': 'North Heatherburgh',
#    'zip': '30515'}},
#  {'_index': 'users',
#   '_source': {'name': 'Anna Copeland',
#    'street': '913 Salas Drives',
#    'city': 'Lake Loriport',
#    'zip': '92608'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jay Young',
#    'street': '43446 Washington Stream',
#    'city': 'Lake Todd',
#    'zip': '99151'}},
#  {'_index': 'users',
#   '_source': {'name': 'Roy Ferguson',
#    'street': '549 Joshua Fork Apt. 677',
#    'city': 'West Cheryl',
#    'zip': '75707'}},
#  {'_index': 'users',
#   '_source': {'name': 'Dr. Kevin Guzman',
#    'street': '98864 Barrera Land',
#    'city': 'Baileybury',
#    'zip': '15914'}},
#  {'_index': 'users',
#   '_source': {'name': 'Megan Jenkins',
#    'street': '00440 Farmer Plains',
#    'city': 'Thompsonbury',
#    'zip': '80644'}},
#  {'_index': 'users',
#   '_source': {'name': 'Corey Bowers',
#    'street': '838 Jose Ridge Apt. 005',
#    'city': 'Lake Carrieburgh',
#    'zip': '56866'}},
#  {'_index': 'users',
#   '_source': {'name': 'Ashley Garner',
#    'street': '29555 Vernon Throughway',
#    'city': 'North Melissaville',
#    'zip': '58713'}},
#  {'_index': 'users',
#   '_source': {'name': 'Lindsey Perez',
#    'street': '63743 Butler Inlet',
#    'city': 'Port Amber',
#    'zip': '87269'}},
#  {'_index': 'users',
#   '_source': {'name': 'Alan Allen',
#    'street': '58003 Lewis Streets Suite 547',
#    'city': 'Devonville',
#    'zip': '51157'}},
#  {'_index': 'users',
#   '_source': {'name': 'Mallory Hendricks',
#    'street': '1604 Jocelyn Manors Apt. 385',
#    'city': 'West Michaelport',
#    'zip': '97706'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jacob Schmitt',
#    'street': '066 Gibson Streets Suite 513',
#    'city': 'Lake Jimmy',
#    'zip': '63478'}},
#  {'_index': 'users',
#   '_source': {'name': 'Rebecca Lee',
#    'street': '98837 Martin Ports Suite 596',
#    'city': 'Juliefort',
#    'zip': '08856'}},
#  {'_index': 'users',
#   '_source': {'name': 'April Smith',
#    'street': '50780 Renee Row Apt. 365',
#    'city': 'Jimenezside',
#    'zip': '18030'}},
#  {'_index': 'users',
#   '_source': {'name': 'Sara Barnes',
#    'street': '1743 Smith Ridge',
#    'city': 'Floresfort',
#    'zip': '11793'}},
#  {'_index': 'users',
#   '_source': {'name': 'Samantha Andrews',
#    'street': '20634 Garrett Village Suite 562',
#    'city': 'South Jennifer',
#    'zip': '14590'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jessica Maldonado',
#    'street': '841 Harris Roads',
#    'city': 'Lake Jameshaven',
#    'zip': '48600'}},
#  {'_index': 'users',
#   '_source': {'name': 'Willie Reyes',
#    'street': '97806 Johnson Plaza',
#    'city': 'East Franciscobury',
#    'zip': '08953'}},
#  {'_index': 'users',
#   '_source': {'name': 'Isaiah Morris',
#    'street': '936 Timothy Crossroad',
#    'city': 'North Tamara',
#    'zip': '60514'}},
#  {'_index': 'users',
#   '_source': {'name': 'Thomas Rivera',
#    'street': '91375 Angela Common Apt. 030',
#    'city': 'South Steventown',
#    'zip': '58699'}},
#  {'_index': 'users',
#   '_source': {'name': 'Gary Bell',
#    'street': '4304 Colin Harbors',
#    'city': 'Port Linda',
#    'zip': '84320'}},
#  {'_index': 'users',
#   '_source': {'name': 'Micheal Alexander',
#    'street': '1239 Mayer Junction Suite 458',
#    'city': 'North Tyler',
#    'zip': '65264'}},
#  {'_index': 'users',
#   '_source': {'name': 'Katherine Vaughn',
#    'street': '50013 Timothy Streets',
#    'city': 'Lake Deanna',
#    'zip': '22385'}},
#  {'_index': 'users',
#   '_source': {'name': 'Ann Peck',
#    'street': '8529 Roy Lodge Apt. 797',
#    'city': 'Port Jennaville',
#    'zip': '44656'}},
#  {'_index': 'users',
#   '_source': {'name': 'Megan Butler',
#    'street': '1086 Barron Lodge',
#    'city': 'Johnsontown',
#    'zip': '31709'}},
#  {'_index': 'users',
#   '_source': {'name': 'David Gardner',
#    'street': '042 Matthew Keys Suite 439',
#    'city': 'South Elizabeth',
#    'zip': '94091'}},
#  {'_index': 'users',
#   '_source': {'name': 'Alexis Morris',
#    'street': '987 Hutchinson Crescent',
#    'city': 'South Amyland',
#    'zip': '42852'}},
#  {'_index': 'users',
#   '_source': {'name': 'Bruce Sweeney',
#    'street': '233 Donna Village Apt. 589',
#    'city': 'Alexandraton',
#    'zip': '26674'}},
#  {'_index': 'users',
#   '_source': {'name': 'Susan Alvarez',
#    'street': '74806 Hill Village Suite 372',
#    'city': 'West Dianefurt',
#    'zip': '08325'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jennifer Lester',
#    'street': '4435 Mosley Glens',
#    'city': 'Andersonside',
#    'zip': '30256'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jonathan Richards',
#    'street': '281 Drake Lights Apt. 946',
#    'city': 'South Charles',
#    'zip': '58915'}},
#  {'_index': 'users',
#   '_source': {'name': 'Patrick Crawford',
#    'street': '16214 Erin Street',
#    'city': 'Romeroport',
#    'zip': '81535'}},
#  {'_index': 'users',
#   '_source': {'name': 'Ashley Quinn',
#    'street': '284 Robert Ways',
#    'city': 'Ayalabury',
#    'zip': '83169'}},
#  {'_index': 'users',
#   '_source': {'name': 'Angela Lee',
#    'street': '56663 Tina Mills Suite 895',
#    'city': 'Danashire',
#    'zip': '21394'}},
#  {'_index': 'users',
#   '_source': {'name': 'Andrea Novak',
#    'street': '0505 Amanda Centers',
#    'city': 'Ashleystad',
#    'zip': '83568'}},
#  {'_index': 'users',
#   '_source': {'name': 'Dawn Ayala DVM',
#    'street': '6953 Kathleen Shoal Apt. 673',
#    'city': 'New Benjaminchester',
#    'zip': '68397'}},
#  {'_index': 'users',
#   '_source': {'name': 'Charles Vargas',
#    'street': '776 Young Stravenue Suite 318',
#    'city': 'Lake Jacobchester',
#    'zip': '24751'}},
#  {'_index': 'users',
#   '_source': {'name': 'Vanessa Rodriguez',
#    'street': '630 Sanchez Fall Suite 221',
#    'city': 'New Laurafurt',
#    'zip': '58573'}},
#  {'_index': 'users',
#   '_source': {'name': 'Frank Allen',
#    'street': '7157 Raymond Underpass Apt. 463',
#    'city': 'New Gabrielburgh',
#    'zip': '49397'}},
#  {'_index': 'users',
#   '_source': {'name': 'Olivia Rivas',
#    'street': '54212 Shawn Neck Apt. 687',
#    'city': 'Mosleyfurt',
#    'zip': '57154'}},
#  {'_index': 'users',
#   '_source': {'name': 'Crystal Cardenas',
#    'street': '24943 Phillips Oval Suite 081',
#    'city': 'New Jorgemouth',
#    'zip': '15318'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kelly Lopez',
#    'street': '2222 Keith Oval',
#    'city': 'North Michael',
#    'zip': '27869'}},
#  {'_index': 'users',
#   '_source': {'name': 'Krista Page',
#    'street': '709 Hall Pass Apt. 626',
#    'city': 'Mayview',
#    'zip': '51524'}},
#  {'_index': 'users',
#   '_source': {'name': 'Lori Hoffman',
#    'street': '229 Wagner Shoals',
#    'city': 'Lewishaven',
#    'zip': '71245'}},
#  {'_index': 'users',
#   '_source': {'name': 'April Brandt',
#    'street': '841 Graham Village Apt. 230',
#    'city': 'North Jessicahaven',
#    'zip': '78374'}},
#  {'_index': 'users',
#   '_source': {'name': 'Joshua Dixon',
#    'street': '320 Michael Lights Apt. 970',
#    'city': 'Fosterbury',
#    'zip': '08143'}},
#  {'_index': 'users',
#   '_source': {'name': 'Curtis Mcgrath',
#    'street': '9760 Debbie Row',
#    'city': 'New Michelleside',
#    'zip': '72761'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kathryn Harper',
#    'street': '744 White Islands',
#    'city': 'Greenview',
#    'zip': '25571'}},
#  {'_index': 'users',
#   '_source': {'name': 'Elizabeth Jennings',
#    'street': '5575 Daniel Harbor',
#    'city': 'Port Kelly',
#    'zip': '32193'}},
#  {'_index': 'users',
#   '_source': {'name': 'Diana Monroe',
#    'street': '17357 Melissa Falls',
#    'city': 'New Joyce',
#    'zip': '80757'}},
#  {'_index': 'users',
#   '_source': {'name': 'Eric Jones',
#    'street': '25097 Hernandez Ford Suite 682',
#    'city': 'New Melissa',
#    'zip': '35685'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jill Smith',
#    'street': '8160 Cathy Stream',
#    'city': 'South Maryborough',
#    'zip': '42988'}},
#  {'_index': 'users',
#   '_source': {'name': 'Penny Russell',
#    'street': '015 Brianna Coves',
#    'city': 'Michaelside',
#    'zip': '30503'}},
#  {'_index': 'users',
#   '_source': {'name': 'Melissa Joseph',
#    'street': '90008 Gardner Corners Suite 232',
#    'city': 'Jamesburgh',
#    'zip': '64726'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jason Mitchell',
#    'street': '32646 Angela Wall Apt. 853',
#    'city': 'Jacksonville',
#    'zip': '54263'}},
#  {'_index': 'users',
#   '_source': {'name': 'Katherine Torres',
#    'street': '2291 Miller Coves',
#    'city': 'Joneston',
#    'zip': '21900'}},
#  {'_index': 'users',
#   '_source': {'name': 'Leslie Bates',
#    'street': '0192 Smith Gateway',
#    'city': 'Lake Jason',
#    'zip': '03026'}},
#  {'_index': 'users',
#   '_source': {'name': 'Brian Spencer',
#    'street': '92498 Heidi Passage',
#    'city': 'New Krystalfurt',
#    'zip': '49405'}},
#  {'_index': 'users',
#   '_source': {'name': 'Tammy Willis',
#    'street': '7932 Kathleen Island',
#    'city': 'Port Robertchester',
#    'zip': '60367'}},
#  {'_index': 'users',
#   '_source': {'name': 'Robert Case',
#    'street': '510 David Land',
#    'city': 'New Trevor',
#    'zip': '65996'}},
#  {'_index': 'users',
#   '_source': {'name': 'Matthew Montoya',
#    'street': '11174 Lisa Road',
#    'city': 'Sanchezshire',
#    'zip': '42071'}},
#  {'_index': 'users',
#   '_source': {'name': 'Diane Hernandez',
#    'street': '4651 Mark Underpass Suite 406',
#    'city': 'Lake Marissafurt',
#    'zip': '41420'}},
#  {'_index': 'users',
#   '_source': {'name': 'Annette Moran',
#    'street': '966 Belinda Ferry Apt. 707',
#    'city': 'Stevenmouth',
#    'zip': '32819'}},
#  {'_index': 'users',
#   '_source': {'name': 'Nichole Mccann',
#    'street': '0138 Gonzalez Ways',
#    'city': 'Lake Ashleyburgh',
#    'zip': '91720'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kelly Salazar',
#    'street': '24848 Jeffrey Inlet',
#    'city': 'North Amyland',
#    'zip': '30900'}},
#  {'_index': 'users',
#   '_source': {'name': 'James Salinas',
#    'street': '23598 Barry Cliffs Suite 475',
#    'city': 'Shawnstad',
#    'zip': '93477'}},
#  {'_index': 'users',
#   '_source': {'name': 'Nicole Johnson',
#    'street': '595 Nicholas Route Suite 868',
#    'city': 'New Ericview',
#    'zip': '21547'}},
#  {'_index': 'users',
#   '_source': {'name': 'Jennifer York',
#    'street': '31131 Melissa Lights',
#    'city': 'North Eduardo',
#    'zip': '94954'}},
#  {'_index': 'users',
#   '_source': {'name': 'Sean Brown',
#    'street': '709 Snyder Mountain',
#    'city': 'Watkinsbury',
#    'zip': '99580'}},
#  {'_index': 'users',
#   '_source': {'name': 'Wesley Simmons',
#    'street': '15457 Henderson Groves',
#    'city': 'Lake Timothy',
#    'zip': '54222'}},
#  {'_index': 'users',
#   '_source': {'name': 'Diane Beck',
#    'street': '109 Adams Expressway Suite 912',
#    'city': 'Mccormickstad',
#    'zip': '01796'}},
#  {'_index': 'users',
#   '_source': {'name': 'Sheena Roberts',
#    'street': '4598 Snyder Throughway Suite 798',
#    'city': 'Darrenville',
#    'zip': '56366'}},
#  {'_index': 'users',
#   '_source': {'name': 'Maria Lewis',
#    'street': '3789 Nancy Turnpike',
#    'city': 'Lozanoberg',
#    'zip': '30313'}},
#  {'_index': 'users',
#   '_source': {'name': 'Stephanie Adams',
#    'street': '823 Brandon Fall Apt. 084',
#    'city': 'Myersland',
#    'zip': '95716'}},
#  {'_index': 'users',
#   '_source': {'name': 'Shawn Henderson',
#    'street': '27649 Victoria Plain Suite 268',
#    'city': 'West Richardport',
#    'zip': '61209'}},
#  {'_index': 'users',
#   '_source': {'name': 'Michelle Cowan',
#    'street': '4153 Carol Inlet Suite 985',
#    'city': 'East Sandyburgh',
#    'zip': '26325'}},
#  {'_index': 'users',
#   '_source': {'name': 'Gary Curtis',
#    'street': '03086 Adams Valleys',
#    'city': 'South Michael',
#    'zip': '07587'}},
#  {'_index': 'users',
#   '_source': {'name': 'Julie Allen',
#    'street': '544 Davis Loaf',
#    'city': 'East Mark',
#    'zip': '65679'}},
#  {'_index': 'users',
#   '_source': {'name': 'Kathryn Stephenson',
#    'street': '7917 Lopez Center',
#    'city': 'Adammouth',
#    'zip': '00845'}},
#  {'_index': 'users',
#   '_source': {'name': 'Francisco Chaney',
#    'street': '561 Theresa Knoll Apt. 240',
#    'city': 'Lake Scott',
#    'zip': '69880'}}]

# %%
res = helpers.bulk(es, actions)
print(res)
# Out:
# (998, [])
